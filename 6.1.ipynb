# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from scipy.stats import beta
from scipy.stats import bernoulli
from scipy.stats import uniform
m=[5, 10, 20, 50, 100]
p=uniform.rvs(size=1)
print(p)
for n in m:
    plt.figure(figsize=(10,5)) 
    x = np.linspace(0, 1 , 1000)
    r = bernoulli.rvs(p, size=n)
    plt.plot(x, beta.pdf(x,1+sum(r),n+1-sum(r)))
# Out:
# [0.88538213]

# %%
m=[5, 10, 20, 50, 100]
for n in m:
    plt.figure(figsize=(8,4)) 
    x = np.linspace(0, 1 , 1000)
    plt.plot(x, beta.pdf(x,1+9*n/10,n+1-9*n/10) )

# %%
m=[5, 10, 20, 50, 100]
for n in m:
    plt.figure(figsize=(8,4)) 
    x = np.linspace(0, 1 , 1000)
    plt.plot(x, beta.pdf(x,1+99*n/100,n+1-99*n/100) )
