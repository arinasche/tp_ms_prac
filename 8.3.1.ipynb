# %% [markdown]
# Для $D\{X_{(1)}>C\}$

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import scipy.stats as sc
p0=[]
p1=[]
p2=[]
def a(x):
    if (1<=x) and (x<=2):
        return((2-x)**100)
    elif  x<1:
        return(1)
    else:
        return(0)
def b(x):
    if (-1<=x) and (x<=0):
        return((-x)**100)
    elif  x<-1:
        return(1)
    else:
        return(0)
for i in range(0,100):
    x=sc.uniform.rvs(size=100)
    p0.append(1-(1-min(x))**100)
    p1.append(1-a(min(x)))
    p2.append(1-b(min(x)))
p0=sorted(p0)
p1=sorted(p1)
p2=sorted(p2)
plt.figure(figsize=(10,5))
x = np.arange(0,1, 1/m)
plt.plot(x, list(map(lambda x: p0[int(x*m)],x)), label = r'$H_{0}: \theta = 0$')
plt.plot(x, list(map(lambda x: p1[int(x*m)],x)), label = r'$H_{1}: \theta = 1$')
plt.plot(x, list(map(lambda x: p2[int(x*m)],x)), label = r'$H_{1}: \theta = -1$')
plt.plot(list(map(lambda x: x,x)), x, label = 'R[0,1]')
plt.legend()
plt.title('$X_{(1)}>C$')
plt.show()

# %%
p0=[]
p1=[]
p2=[]
def a(x):
    if (1<=x) and (x<=2):
        return((x-1)**100)
    elif  x<1:
        return(0)
    else:
        return(1)
def b(x):
    if (-1<=x) and (x<=0):
        return((x+1)**100)
    elif  x<-1:
        return(0)
    else:
        return(1)
for i in range(0,100):
    x=sc.uniform.rvs(size=100)
    p0.append(1-max(x)**100)
    p1.append(1-a(max(x)))
    p2.append(1-b(max(x)))
p0=sorted(p0)
p1=sorted(p1)
p2=sorted(p2)
plt.figure(figsize=(10,5))
x = np.arange(0,1, 1/m)
plt.plot(x, list(map(lambda x: p0[int(x*m)],x)), label = r'$H_{0}: \theta = 0$')
plt.plot(x, list(map(lambda x: p1[int(x*m)],x)), label = r'$H_{0}: \theta = 1$')
plt.plot(x, list(map(lambda x: p2[int(x*m)],x)), label = r'$H_{0}: \theta = -1$')
plt.plot(list(map(lambda x: x,x)), x, label = 'R[0,1]')
plt.legend()
plt.title('$X_{(n)}>C$')
plt.show()
