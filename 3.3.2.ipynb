# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
x=np.random.normal(0,1,1000)
sb.distplot(x)

# %%
y=np.random.standard_cauchy(1000)
sb.distplot(y)

# %%
plt.figure(figsize = (8,6))
sb.distplot(x) 
sb.distplot(y)

# %% [markdown]
# $X,Y$-н.о.р $N(0,1)$ <p>
# $(X+Y) \sim N(0,2)$ <p>
# $(X-Y)\sim N(0,2)$

# %%
plt.figure(figsize = (10,10))
mean, cov = [0, 0], [(2, 0), (0, 2)]
x, y = np.random.multivariate_normal(mean, cov, size=1000).T
sb.kdeplot(x, y, n_levels=30, cmap="Purples_d");
