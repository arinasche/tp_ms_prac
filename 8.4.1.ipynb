# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import scipy.stats as sc
m=[1,5,10,50,100,500,1000]
def p(x):
    return(0.05)
for n in m:
    plt.figure(figsize=(15,5))
    x = np.linspace(0, 1 , 1000)
    plt.plot(x,sc.binom.cdf(x*n, n, 0.5),label = '1')
    plt.plot(x,1-sc.binom.cdf(x*n, n, 1/3),label = '2')
    plt.plot(x, list(map(lambda x: 0.05,x)))
    plt.legend()
    plt.title(n)
    plt.show()
