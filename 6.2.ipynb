# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from scipy.stats import beta
from scipy.stats import bernoulli
from scipy.stats import uniform
m=[5, 10, 20, 50, 100]
a=2
b=5
p=beta.rvs(a, b, size=1)
print(p)
for n in m:
    plt.figure(figsize=(10,5)) 
    x = np.linspace(0, 1 , 1000)
    r = bernoulli.rvs(p, size=n)
    plt.plot(x, beta.pdf(x,a+sum(r),n+b-sum(r)))
# Out:
# [0.2103594]

# %%
m=[5, 10, 20, 50, 100]
for n in m:
    plt.figure(figsize=(8,4)) 
    x = np.linspace(0, 1 , 1000)
    plt.plot(x, beta.pdf(x,a+9*n/10,n+b-9*n/10) )

# %%
m=[5, 10, 20, 50, 100]
for n in m:
    plt.figure(figsize=(8,4)) 
    x = np.linspace(0, 1 , 1000)
    plt.plot(x, beta.pdf(x,a+99*n/100,n+b-99*n/100) )
